# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

import nltk
import re
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer

# %%
df = pd.read_csv("/content/news_articles.csv")

# %%
df.sample(5)
# Out:
#                  author                      published  \
# 1049  Daniel Greenfield  2016-10-27T20:39:44.307+03:00
# 67            Anonymous  2016-10-26T22:19:00.000+03:00
# 63            Anonymous  2016-10-26T22:19:00.000+03:00
# 1553          No Author  2016-10-27T04:38:00.901+03:00
# 579           No Author  2016-10-30T13:10:51.667+02:00
#
#                                                   title  \
# 1049  wife of fbi official investigating hillary got...
# 67                                             no title
# 63                                             no title
# 1553  israel settlements legal trump aide says playi...
# 579   from the beginning of this year zionist regime...
#
#                                                    text language  \
# 1049  obamacare is great we just need to punish peop...  english
# 67    he has got to go after him  he is the one caus...  english
# 63    he has got to go after him  he is the one caus...  english
# ...

# %%
df = df.astype(str)

# %%
text = df['title'].astype(str).tolist()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2096 entries, 0 to 2095
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   author                   2096 non-null   object
#  1   published                2096 non-null   object
#  2   title                    2096 non-null   object
#  3   text                     2096 non-null   object
#  4   language                 2096 non-null   object
#  5   site_url                 2096 non-null   object
#  6   main_img_url             2096 non-null   object
#  7   type                     2096 non-null   object
#  8   label                    2096 non-null   object
#  9   title_without_stopwords  2096 non-null   object
#  10  text_without_stopwords   2096 non-null   object
#  11  hasImage                 2096 non-null   object
# dtypes: object(12)
# memory usage: 196.6+ KB

# %%
df.describe()
# Out:
#            author                      published     title  text language  \
# count        2096                           2096      2096  2096     2096
# unique        491                           2006      1784  1942        6
# top     No Author  2016-11-01T13:00:00.000+02:00  no title   nan  english
# freq          505                              8       186    46     2017
#
#                 site_url  main_img_url  type label title_without_stopwords  \
# count               2096          2096  2096  2096                    2096
# unique                69          1230     9     3                    1781
# top     frontpagemag.com  No Image URL    bs  Fake                   title
# freq                 100           466   601  1294                     187
#
#        text_without_stopwords hasImage
# count                    2096     2096
# unique                   1938        3
# top                       nan      1.0
# freq                       50     1628

# %%
df.isnull().sum()
# Out:
# author                     0
# published                  0
# title                      0
# text                       0
# language                   0
# site_url                   0
# main_img_url               0
# type                       0
# label                      0
# title_without_stopwords    0
# text_without_stopwords     0
# hasImage                   0
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# author                     0
# published                  0
# title                      0
# text                       0
# language                   0
# site_url                   0
# main_img_url               0
# type                       0
# label                      0
# title_without_stopwords    0
# text_without_stopwords     0
# hasImage                   0
# dtype: int64

# %%
y= df['label']
le = LabelEncoder()
df['label'] = le.fit_transform(df['label'])
print(df.head())
# Out:
#                  author                      published  \
# 0     Barracuda Brigade  2016-10-26T21:41:00.000+03:00
# 1  reasoning with facts  2016-10-29T08:47:11.259+03:00
# 2     Barracuda Brigade  2016-10-31T01:41:49.479+02:00
# 3                Fed Up  2016-11-01T05:22:00.000+02:00
# 4                Fed Up  2016-11-01T21:56:00.000+02:00
#
#                                                title  \
# 0  muslims busted they stole millions in govt ben...
# 1  re why did attorney general loretta lynch plea...
# 2  breaking weiner cooperating with fbi on hillar...
# 3  pin drop speech by father of daughter kidnappe...
# 4  fantastic trumps  point plan to reform healthc...
#
#                                                 text language  \
# 0  print they should pay all the back all the mon...  english
# 1  why did attorney general loretta lynch plead t...  english
# 2  red state  \nfox news sunday reported this mor...  english
# ...

# %%
df.sample(2)
# Out:
#           author                      published  \
# 160       SyxPak  2016-10-27T02:55:02.683+03:00
# 170  frenchfries  2016-10-27T11:15:29.892+03:00
#
#                                    title  \
# 160             it will come for you all
# 170  letter for mr smith  part  the main
#
#                                                   text language  \
# 160  a reply to windword shall i post videos of hil...  english
# 170  erb trump vs clinton is finally here page  lin...  english
#
#                site_url                                      main_img_url  \
# 160  abovetopsecret.com  http://files.abovetopsecret.com/images/ats16.jpg
# 170  abovetopsecret.com   http://files.abovetopsecret.com/images/ats8.jpg
#
#     type  label    title_without_stopwords  \
# 160   bs      0                       come
# 170   bs      0  letter mr smith part main
#
#                                 text_without_stopwords hasImage
# 160  reply windword shall post videos hillary laugh...      1.0
# ...

# %%
df_exsting = df.columns


df_drop = ['published', 'language', 'site_url', 'main_img_url', 'type', 'title_without_stopwords', 'text_without_stopwords', 'hasImage']

valid_columns_to_drop = [col for col in df_drop if col in df_exsting]
df = df.drop(columns = valid_columns_to_drop)

df.sample(2)
# Out:
#                          author                                         title  \
# 2083                -NO AUTHOR-  boycott targets trump family on retail front
# 1956  Karin Zakrzewski-Graziano                                      no title
#
#                                                    text  label
# 2083                                                nan      1
# 1956  woman eaten alive by daughters dogs  german sh...      1

# %%
df['texts'] = df['author'] + df['title'] + df['text']

# %%
df = df.drop(columns = ['author', 'title', 'text'])

# %%
df['texts'] = df['texts'].apply(lambda x: "".join(x))
df.head()
# Out:
#    label                                              texts
# 0      1  Barracuda Brigademuslims busted they stole mil...
# 1      1  reasoning with factsre why did attorney genera...
# 2      1  Barracuda Brigadebreaking weiner cooperating w...
# 3      1  Fed Uppin drop speech by father of daughter ki...
# 4      1  Fed Upfantastic trumps  point plan to reform h...

# %%
df
# Out:
#       label                                              texts
# 0         1  Barracuda Brigademuslims busted they stole mil...
# 1         1  reasoning with factsre why did attorney genera...
# 2         1  Barracuda Brigadebreaking weiner cooperating w...
# 3         1  Fed Uppin drop speech by father of daughter ki...
# 4         1  Fed Upfantastic trumps  point plan to reform h...
# ...     ...                                                ...
# 2091      1  -NO AUTHOR-teens walk free after gangrape conv...
# 2092      1  -NO AUTHOR-school named for munichmassacre mas...
# 2093      0        -NO AUTHOR-russia unveils satan  missilenan
# 2094      0  -NO AUTHOR-check out hillarythemed haunted hou...
# 2095      2  Eddy Lavinecannabis aficionados develop thca c...
#
# [2096 rows x 2 columns]

# %%
# !python -m spacy download en_core_web_lg
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.7/400.7 MB 2.3 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy
nlp = spacy.load("en_core_web_lg")

# %%
df['vector'] = df['texts'].apply(lambda text: nlp(text).vector)

# %%
df.head()
# Out:
#    label                                              texts  \
# 0      1  Barracuda Brigademuslims busted they stole mil...
# 1      1  reasoning with factsre why did attorney genera...
# 2      1  Barracuda Brigadebreaking weiner cooperating w...
# 3      1  Fed Uppin drop speech by father of daughter ki...
# 4      1  Fed Upfantastic trumps  point plan to reform h...
#
#                                               vector
# 0  [-0.09774128, 0.055214263, -0.10248231, -0.021...
# 1  [-0.095637, 0.09069608, -0.0722986, 0.06171581...
# 2  [-0.057801187, 0.110673495, -0.10309944, 0.028...
# 3  [-0.09626302, 0.17611563, -0.06345817, 0.08335...
# 4  [-0.04763851, 0.09105905, -0.05606046, -0.0122...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, BaggingClassifier, ExtraTreesClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier

# %%
svc = SVC(kernel = "sigmoid", gamma = 1.0)
knc = KNeighborsClassifier()
dtc = DecisionTreeClassifier(max_depth = 5)
lrc = LogisticRegression(solver = 'liblinear', penalty = "l1")
rfc = RandomForestClassifier(n_estimators = 50, random_state = 2)
abc = AdaBoostClassifier(n_estimators = 50, random_state = 2)
bc = BaggingClassifier(n_estimators = 50, random_state = 2)
etc = ExtraTreesClassifier(n_estimators = 50, random_state = 2)
gbbc = GradientBoostingClassifier(n_estimators = 50, random_state = 2)
xgb = XGBClassifier(n_estimators = 50, random_state = 2)

# %%
clfs = {
    "svc" : svc,
    "knc" : knc,
    "dtc" : dtc,
    "lrc" : lrc,
    "rfc" : rfc,
    "abc" : abc,
    "bc" : bc,
    "etc" : etc,
    "xgb" : xgb
}

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(
    df.vector.values,
    df.label,
    test_size = 0.2,
    random_state = 42
)

# %%
x_train = np.stack(x_train)
x_test = np.stack(x_test)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaled_train_embed = scaler.fit_transform(x_train)
scaled_test_embed = scaler.transform(x_test)

# %%
from sklearn.metrics import accuracy_score, precision_score

def train_classifier(clfs, X_train, y_train, X_test, y_test):
    clfs.fit(X_train, y_train)
    y_pred = clfs.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    return accuracy, precision

# %%
accuracy_scores = []
precision_scores = []
for name , clfs in clfs.items():
    current_accuracy, current_precision = train_classifier(clfs, x_train, y_train, x_test, y_test)
    print()
    print("For: ", name)
    print("Accuracy: ", current_accuracy)
    print("Precision: ", current_precision)

    accuracy_scores.append(current_accuracy)
    precision_scores.append(current_precision)
# Out:
# For:  svc
# Accuracy:  0.49523809523809526
# Precision:  0.3312883435582822
#
# For:  knc
# Accuracy:  0.6547619047619048
# Precision:  0.5447761194029851
#
# For:  dtc
# Accuracy:  0.6095238095238096
# Precision:  0.4588235294117647
#
# For:  lrc
# Accuracy:  0.6928571428571428
# Precision:  0.6428571428571429
#
# For:  rfc
# Accuracy:  0.6952380952380952
# Precision:  0.6464646464646465
#
# For:  abc
# Accuracy:  0.4095238095238095
# Precision:  0.38596491228070173
#
# For:  bc
# Accuracy:  0.6904761904761905
# Precision:  0.6336633663366337
#
# For:  etc
# Accuracy:  0.6880952380952381
# Precision:  0.6444444444444445
#
# For:  xgb
# Accuracy:  0.6928571428571428
# Precision:  0.6129032258064516
